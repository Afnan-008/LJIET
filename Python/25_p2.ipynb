# %%
for i in range(1,11,2):
    print("Hello")
    print(i)
# Out:
# Hello
# 1
# Hello
# 3
# Hello
# 5
# Hello
# 7
# Hello
# 9

# %%
d = {10:'Arman', 20:'Khamzat', 30:'Khabib', 20:'Mufaddal'}
print(d)
print(type(d))
print(d[10])
print(d[20])
# Out:
# {10: 'Arman', 20: 'Mufaddal', 30: 'Khabib'}
# <class 'dict'>
# Arman
# Mufaddal

# %%
s = {3,7,8,4,4,5,5,1,1,3,4}
print(s)
print(type(s))
# Out:
# {1, 3, 4, 5, 7, 8}
# <class 'set'>

# %%
X = {"apple","banana","cherry"}
print(X)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
a = frozenset(s)
print(a)
print(type(a))
# Out:
# frozenset({1, 3, 4, 5, 7, 8})
# <class 'frozenset'>

# %%
print(20>8)
print(20==8)
print(20<8)
# Out:
# True
# False
# False

# %%
print(bool("abc"))
print(bool(""))
print(bool(123))
print(bool([1,2,3,4,5]))
print(bool(0))
# Out:
# True
# False
# True
# True
# False

# %%
x = 1,2,3,4
a,b,c,d = 1,2,3,4
print(x)
print(a)
print(b)
print(c)
print(d)
# Out:
# (1, 2, 3, 4)
# 1
# 2
# 3
# 4

# %%
a = "Global"
def demo():
    a = "Local"
    print(a)
demo()
print(a)
# Out:
# Local
# Global

# %%
a = "Global"
def demo():
    global a
    a = "Global in Function"
    print(a)
demo()
print(a)
# Out:
# Global in Function
# Global in Function

# %%
s = input("Enter Data:")
print(s)
print(type(s))
# Out:
# Enter Data: afnan
# afnan
# <class 'str'>

# %%
a = int(input("Enter a : "))
b = int(input("Enter b : "))
c = a+b
print ("Sum : ",a+b)
print(c)
# Out:
# Enter a :  10
# Enter b :  20
# Sum :  30
# 30

# %%
print(int(123.987))
print(int(True))
print(int(False))
print(int("10"))
#print(int("10.5"))
#print(int("ten"))
#print(int("0B1111"))
# Out:
# 123
# 1
# 0
# 10

# %%
print(float(10))
print(float(True))
print(float(False))
print(float("10"))
print(float("10.5"))
#print(float("ten"))
#print(float("0B1111"))
# Out:
# 10.0
# 1.0
# 0.0
# 10.0
# 10.5

# %%
print(str(10))
print(str(10.5))
print(str(True))
print(str(False))
# Out:
# 10
# 10.5
# True
# False

# %%
print(bool(0))
print(bool(1))
print(bool(10.5))
print(bool(0.178))
print(bool(0.0))
print(bool("True"))
print(bool("False"))
# Out:
# False
# True
# True
# True
# False
# True
# True

# %%
a = "LJ"
b = "IET"
print((a+b)*2)
print(a+b)
# Out:
# LJIETLJIET
# LJIET

# %%
var1=int(input("Enter num-1 : "))
var2=int(input("Enter num-2 : "))
print(var1+var2,'add')
print(var1-var2,'sub')
print(var1*var2,'mult')
print(var1/var2,'div')
print(var1%var2,'modulo')
print(var1//var2,'floor')
print(var1**var2,'power')
# Out:
# Enter num-1 :  1
# Enter num-2 :  2
# 3 add
# -1 sub
# 2 mult
# 0.5 div
# 1 modulo
# 0 floor
# 1 power

# %%
12.0//5
# Out:
# 2.0

# %%
12//5
# Out:
# 2

# %%
100/5
# Out:
# 20.0

# %%
var1=5
var2=6
print(var1==var2)
print(var1!=var2)
print(var1>var2)
print(var1<var2)
print(var1>=var2)
print(var1<=var2)
print(1=='1.0')
print(var1==var2)
# Out:
# False
# True
# False
# True
# False
# True
# False
# False

# %%
print(True>5)
print(True>=True)
print(10<20<30)
# Out:
# False
# True
# True

# %%
a = 'arman'
b = 'Aryan'
print (a>b)
print (a<b)
# Out:
# True
# False

# %%
ord("$")
# Out:
# 36

# %%
chr(36)
# Out:
# '$'

# %%
# For Boolean Type
print(5>2 and 7>6)
print(0>2 and 4<6)
print(7<2 or 1>0)     
print(not True)
print(not False)
print(not 0)
print(not 1)
# Out:
# True
# False
# True
# False
# True
# True
# False

# %%
# For Non-Boolean Type
print(10 and 20)
print(0 and 20)
print(10 or 20)
print(0 or 20)
print(20 or 20)
print(not 20)
print(not 0)
# Out:
# 20
# 0
# 10
# 20
# 20
# False
# True

# %%
X = True if 10*10==10**2 else False
print(X)
# Out:
# True

# %%
x = "Python is very easy."
print("I" in x)
print("i" in x)
print("Y" not in x)
print("Java" in x)
print("Python" in x)
print("." in x)
# Out:
# False
# True
# True
# False
# True
# True

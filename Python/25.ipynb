# %%
print("hello")
# Out:
# hello

# %%
a=10
b=5
print("a =",a)
print("b =",b)
a=a+b
b=a-b
a=a-b
print("a =",a)
print("b =",b)
# Out:
# a = 10
# b = 5
# a = 5
# b = 10

# %%
a=10
b=5
print(a-b)
# Out:
# 5

# %%
print(a*b)
# Out:
# 50

# %%
print(a-b)
# Out:
# 5

# %% [markdown]
# # THIS IS **MARKDOWN**

# %% [markdown]
# 123

# %%
import keyword

# %%
print(hex(0o12345))
# Out:
# 0x14e5

# %%
# Out:
# 324
